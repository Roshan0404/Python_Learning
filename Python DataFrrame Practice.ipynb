# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\roshan.c.kumar.singh\Desktop\Change\ohana-api-master\ohana-api-master\data\sample-csv\locations.csv")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df_ex1=pd.read_excel(r"C:\Users\roshan.c.kumar.singh\Desktop\Misclenaeous\Deployment Margins\BPCRM_ACI_Deployment_202 01 01_MARGINS_ETL_Change_Inventory.xlsx",sheet_name=0)
df_ex2=pd.read_excel(r"C:\Users\roshan.c.kumar.singh\Desktop\Misclenaeous\Deployment Margins\BPCRM_ACI_Deployment_202 01 01_MARGINS_ETL_Change_Inventory.xlsx",sheet_name=1)
df_ex3=pd.read_excel(r"C:\Users\roshan.c.kumar.singh\Desktop\Misclenaeous\Deployment Margins\BPCRM_ACI_Deployment_202 01 01_MARGINS_ETL_Change_Inventory.xlsx",sheet_name=2)
df_ex4=pd.read_excel(r"C:\Users\roshan.c.kumar.singh\Desktop\Misclenaeous\Deployment Margins\BPCRM_ACI_Deployment_202 01 01_MARGINS_ETL_Change_Inventory.xlsx",sheet_name=3)

# %%
df_ex1
# Out:
#     S.No                            ETL Job List New/Existing Region Comments
# 0      1       AT_ENDR_SALESLINE_EPOS_PS_STG 4.1     Existing     AT   CR 231
# 1      2            Full_Refresh_Daily_Table 0.9     Existing     AT   CR 231
# 2      3            Full_Refresh_Month_Table 0.8     Existing     AT   CR 231
# 3      4             Full_Refresh_Week_Table 0.8     Existing     AT   CR 231
# 4      5     Incremental_Refresh_Daily_Table 0.7     Existing     AT   CR 231
# 5      6     Incremental_Refresh_Month_Table 0.7     Existing     AT   CR 231
# 6      7      Incremental_Refresh_Week_Table 0.8     Existing     AT   CR 231
# 7      8  Refresh_full_EPOS_ParentPromo_Main 2.6     Existing     AT   CR 231
# 8      9    NL_ENDR_RESET_SALESLINE_EPOS_PS 0.11     Existing     NL   CR 231
# 9     10                 NL_ENDR_EPOS_PS_STG 0.4     Existing     NL   CR 231
# 10    11            Full_Refresh_Daily_Table 0.8     Existing     NL   CR 231
# ...

# %%
df_ex2
# Out:
#     S.No           Schema                                   Table List  \
# 0      1  sc_warehouse_at  f_salesline_epos_anlts_ps_endr_epos_item_at
# 1      2  sc_warehouse_nl          anlts_ps_endr_epos_product_sales_nl
# 2      3     warehouse_ch       f_salesline_epos_anlts_ps_epos_item_ch
# 3      4     warehouse_ch                   df_epos_daily_unrestricted
# 4      5     warehouse_ch                    df_epos_week_unrestricted
# 5      6     warehouse_ch                    df_epos_week_unrestricted
# 6      7  sc_warehouse_at        rpt_epos_product_cons_day_data_at_new
# 7      8  sc_warehouse_at       rpt_epos_product_cons_week_data_at_new
# 8      9  sc_warehouse_at      rpt_epos_product_cons_month_data_at_new
# 9     10  sc_warehouse_nl        rpt_epos_product_cons_day_data_at_new
# 10    11  sc_warehouse_nl       rpt_epos_product_cons_week_data_at_new
# 11    12  sc_warehouse_nl      rpt_epos_product_cons_month_data_at_new
# ...

# %%
df_ex3
# Out:
#     S.No                  View List New/Existing
# 0      1  R__view_ddl_drop_sc_wh_at     Existing
# 1      2  R__view_ddl_drop_sc_wh_nl     Existing
# 2      3  R__view_ddl_drop_sc_wh_de     Existing
# 3      4  R__view_ddl_drop_sc_wh_pl     Existing
# 4      5  R__view_ddl_drop_sc_wh_uk     Existing
# 5      6     R__view_ddl_drop_wh_ch     Existing
# 6      7       R__view_ddl_sc_wh_at     Existing
# 7      8       R__view_ddl_sc_wh_nl     Existing
# 8      9       R__view_ddl_sc_wh_de     Existing
# 9     10       R__view_ddl_sc_wh_pl     Existing
# 10    11       R__view_ddl_sc_wh_uk     Existing
# 11    12          R__view_ddl_wh_ch     Existing

# %%
df_ex4
# Out:
#    S.No      Config File List New/Existing        Type Region
# 0     1  F_Salesline_Epos.txt     Existing  Batch File     NL

# %%
df_html=pd.read_html("https://www.basketball-reference.com/")

# %%
df_html
# Out:
# [          East Unnamed: 1 Unnamed: 2   W   L
#  0    PHI * (1)          F          $  49  23
#  1    BRK * (2)          F          $  48  24
#  2    MIL * (3)          F          $  46  26
#  3    NYK * (4)          F          $  41  31
#  4    ATL * (5)          F          $  41  31
#  5    MIA * (6)          F          $  40  32
#  6    BOS * (7)          F          $  36  36
#  7    WAS * (8)          F          $  34  38
#  8    IND x (9)          F          $  34  38
#  9   CHO x (10)          F          $  33  39
#  10  CHI x (11)          F          $  31  41
#  11  TOR x (12)          F          $  27  45
#  12  CLE x (13)          F          $  22  50
#  13  ORL x (14)          F          $  21  51
#  14  DET x (15)          F          $  20  52,
#            West Unnamed: 1 Unnamed: 2   W   L
#  0    UTA * (1)          F          $  52  20
#  1    PHO * (2)          F          $  51  21
#  2    DEN * (3)          F          $  47  25
# ...

# %%
len(df_html)
# Out:
# 21

# %%
df_html[20].dtypes
# Out:
# Unnamed: 0_level_0  Team     object
# Knockout Stage      W         int64
#                     L         int64
#                     W/L%    float64
# dtype: object

# %%
df_ex2.columns
# Out:
# Index(['S.No', 'Schema', 'Table List', 'New/Existing', 'CR/Defect'], dtype='object')

# %%
df_ex2[['Schema', 'Table List']]
# Out:
#              Schema                                   Table List
# 0   sc_warehouse_at  f_salesline_epos_anlts_ps_endr_epos_item_at
# 1   sc_warehouse_nl          anlts_ps_endr_epos_product_sales_nl
# 2      warehouse_ch       f_salesline_epos_anlts_ps_epos_item_ch
# 3      warehouse_ch                   df_epos_daily_unrestricted
# 4      warehouse_ch                    df_epos_week_unrestricted
# 5      warehouse_ch                    df_epos_week_unrestricted
# 6   sc_warehouse_at        rpt_epos_product_cons_day_data_at_new
# 7   sc_warehouse_at       rpt_epos_product_cons_week_data_at_new
# 8   sc_warehouse_at      rpt_epos_product_cons_month_data_at_new
# 9   sc_warehouse_nl        rpt_epos_product_cons_day_data_at_new
# 10  sc_warehouse_nl       rpt_epos_product_cons_week_data_at_new
# 11  sc_warehouse_nl      rpt_epos_product_cons_month_data_at_new
# 12  sc_warehouse_de        rpt_epos_product_cons_day_data_at_new
# ...

# %%
#titanic data set
ttnc=pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
ttnc.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
ttnc.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
ttnc[ttnc.dtypes[ttnc.dtypes=='object'].index].describe()
# Out:
#                                         Name   Sex    Ticket Cabin Embarked
# count                                    891   891       891   204      889
# unique                                   891     2       681   147        3
# top     Hogeboom, Mrs. John C (Anna Andrews)  male  CA. 2343    G6        S
# freq                                       1   577         7     4      644

# %%
ttnc[ttnc.dtypes[ttnc.dtypes=='object'].index]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
ttnc.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
type(ttnc['Pclass'])
# Out:
# pandas.core.series.Series

# %%
ttnc['Pclass'][0:5]
# Out:
# 0    3
# 1    1
# 2    3
# 3    1
# 4    3
# Name: Pclass, dtype: int64

# %%
pd.Categorical(ttnc['Ticket'])
# Out:
# ['A/5 21171', 'PC 17599', 'STON/O2. 3101282', '113803', '373450', ..., '211536', '112053', 'W./C. 6607', '111369', '370376']
# Length: 891
# Categories (681, object): ['110152', '110413', '110465', '110564', ..., 'W./C. 6609', 'W.E.P. 5734', 'W/C 14208', 'WE/P 5735']

# %%
ttnc.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
import numpy as np

# %%
ttnc.iloc[np.where(ttnc['Age'].isnull()==True)]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
#Names of people who paid max fare
ttnc.iloc[np.where(ttnc['Fare']==max(ttnc['Fare']))]['Name'].count()
# Out:
# 3

# %%
#Names of people who survived
ttnc.iloc[np.where(ttnc['Survived']==1)]['Name'].count()
# Out:
# 342

# %%
from numpy.random import randn as rn

# %%
df1=pd.DataFrame(rn(5,5),index=['a','b','c','d','e'],columns=['x','y','z','u','v'])

# %%
df1
# Out:
#           x         y         z         u         v
# a  1.019150  0.307379 -0.514091  0.390061  0.010261
# b -1.516540  0.424071  0.336008  1.300864  0.278108
# c  0.115386 -0.045550  0.542513  0.848498  0.655574
# d -1.725336 -0.577771  0.100155 -0.763897 -0.563618
# e -0.456339 -0.439290  1.603951 -1.225249  1.258544

# %%
df1.iloc[0:2][0:]
# Out:
#          x         y         z         u         v
# a  1.01915  0.307379 -0.514091  0.390061  0.010261
# b -1.51654  0.424071  0.336008  1.300864  0.278108

# %%
df1.loc[['a','d']][['x','y','z','u','v']]
# Out:
#           x         y         z         u         v
# a  1.019150  0.307379 -0.514091  0.390061  0.010261
# d -1.725336 -0.577771  0.100155 -0.763897 -0.563618

# %%
df1['new_col']=df1['x']+df1['y']

# %%
df1
# Out:
#           x         y         z         u         v   new_col
# a  1.019150  0.307379 -0.514091  0.390061  0.010261  1.326529
# b -1.516540  0.424071  0.336008  1.300864  0.278108 -1.092469
# c  0.115386 -0.045550  0.542513  0.848498  0.655574  0.069836
# d -1.725336 -0.577771  0.100155 -0.763897 -0.563618 -2.303107
# e -0.456339 -0.439290  1.603951 -1.225249  1.258544 -0.895629

# %%
df1.drop('new_col',axis=1,inplace=True)

# %%
df1
# Out:
#           x         y         z         u         v
# a  1.019150  0.307379 -0.514091  0.390061  0.010261
# b -1.516540  0.424071  0.336008  1.300864  0.278108
# c  0.115386 -0.045550  0.542513  0.848498  0.655574
# d -1.725336 -0.577771  0.100155 -0.763897 -0.563618
# e -0.456339 -0.439290  1.603951 -1.225249  1.258544

# %%
ttnc.drop(np.where(ttnc['Age'].isnull()==True)[0])
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
ttnc.shape
# Out:
# (891, 12)

# %%
df1
# Out:
#           x         y         z         u         v
# a  1.019150  0.307379 -0.514091  0.390061  0.010261
# b -1.516540  0.424071  0.336008  1.300864  0.278108
# c  0.115386 -0.045550  0.542513  0.848498  0.655574
# d -1.725336 -0.577771  0.100155 -0.763897 -0.563618
# e -0.456339 -0.439290  1.603951 -1.225249  1.258544

# %%
df1.iloc[[0,1]]
# Out:
#          x         y         z         u         v
# b -1.51654  0.424071  0.336008  1.300864  0.278108

# %%
df1.iloc[np.where(df1['z']<0)[0]]
# Out:
#          x         y         z         u         v
# a  1.01915  0.307379 -0.514091  0.390061  0.010261

# %%
df1.reset_index()
# Out:
#   index         x         y         z         u         v
# 0     a  1.019150  0.307379 -0.514091  0.390061  0.010261
# 1     b -1.516540  0.424071  0.336008  1.300864  0.278108
# 2     c  0.115386 -0.045550  0.542513  0.848498  0.655574
# 3     d -1.725336 -0.577771  0.100155 -0.763897 -0.563618
# 4     e -0.456339 -0.439290  1.603951 -1.225249  1.258544

# %%
df1.set_index('v')
# Out:
#                   x         y         z         u
# v
#  0.010261  1.019150  0.307379 -0.514091  0.390061
#  0.278108 -1.516540  0.424071  0.336008  1.300864
#  0.655574  0.115386 -0.045550  0.542513  0.848498
# -0.563618 -1.725336 -0.577771  0.100155 -0.763897
#  1.258544 -0.456339 -0.439290  1.603951 -1.225249

# %%
df2=pd.DataFrame({'A':[1,2,np.nan],'B':[5,np.nan,6],'C':[9,5,7]})

# %%
df2['LABELS']="CA NA PL".split()

# %%
df2.set_index('LABELS',inplace=True)

# %%
df2
# Out:
#           A    B  C
# LABELS
# CA      1.0  5.0  9
# NA      2.0  NaN  5
# PL      NaN  6.0  7

# %%
df2.dropna(axis=0)
# Out:
#           A    B  C
# LABELS
# CA      1.0  5.0  9

# %%
df2.dropna(axis=1)
# Out:
#         C
# LABELS
# CA      9
# NA      5
# PL      7

# %%
df2.dropna(axis=1,thresh=3)
# Out:
#         C
# LABELS
# CA      9
# NA      5
# PL      7

# %% [markdown]
# ###

# %%
ttnc.groupby('Sex').mean()['Fare']
# Out:
# Sex
# female    44.479818
# male      25.523893
# Name: Fare, dtype: float64

# %%
df9=ttnc.iloc[0:5,0:5]

# %%
df10=df9

# %%
df11=df10

# %%
pd.concat([df9,df10,df11])
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male
# ...

# %%
pd.concat([df9,df10,df11],axis=1)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  PassengerId  \
# 0                            Braund, Mr. Owen Harris    male            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female            2
# 2                             Heikkinen, Miss. Laina  female            3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female            4
# 4                           Allen, Mr. William Henry    male            5
#
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# ...

# %%
ttnc.sort_values('Fare',ascending=False)
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 737          738         1       1              Lesurer, Mr. Gustave J
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 88            89         1       1          Fortune, Miss. Mabel Helen
# 27            28         0       1      Fortune, Mr. Charles Alexander
# ..           ...       ...     ...                                 ...
# 633          634         0       1       Parr, Mr. William Henry Marsh
# 413          414         0       2      Cunningham, Mr. Alfred Fleming
# 822          823         0       1     Reuchlin, Jonkheer. John George
# 732          733         0       2                Knight, Mr. Robert J
# 674          675         0       2          Watson, Mr. Ennis Hastings
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# ...

# %%
ttnc.sort_index()
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
